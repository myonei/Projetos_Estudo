# %% [markdown]
# # Airline passenger satisfaction dataset

# %% [markdown]
# ### Conteúdo deste dataset
#
# | Feature | Detalhes |
# | -: | :- |
# |**Gender**| Sexo do passageiro (Female, Male)|
# |**Customer Type**| Tipo de cliente (Loyal customer, disloyal customer)
# |**Age**| A idade do passageiro
# |**Type of Travel**| Propósito da viagem (Personal Travel, Business Travel)
# |**Class**| Cabine referente à passagem comprada (Business, Eco, Eco Plus)
# |**Flight distance**| Distância percorrida na viagem
# |**Inflight wifi service**| Nível de satisfação com o wifi (0**\|Not Applicable;1-5)
# |**Departure/Arrival time convenient**| Nível de satisfação com relação ao horário de saída e chegada
# |**Ease of Online booking**| nível de satisfação com as reservas online
# |**Gate location**| Nível de satisfação com a localização do portão
# |**Food and drink**| Nível de satisfação com comidas e bebidas
# |**Online boarding**| Nível de satisfação com online boarding
# |**Seat comfort**| Nível de satisfação com o conforto dos assentos
# |**Inflight entertainment**| Nível de satisfação com o entretenimento durante o voo
# |**On-board service**| Nível de satisfação com o serviço on-board
# |**Leg room service**| Nível de satisfação com relação ao espaço para as pernas
# |**Baggage handling**| Nível de satisfação com o cuidado com as bagagens
# |**Check-in service**| Nível de satisfação com os serviços de check in
# |**Inflight service**| Nível de satisfação durante o voo
# |**Cleanliness**| Nível de satisfação com a limpeza
# |**Departure Delay in Minutes**| Atrasos para saída do voo em minutos
# |**Arrival Delay in Minutes**| Atrasos na chegada em minutos
# |**Satisfaction**| Nível de satisfação(Satisfaction, neutral or dissatisfaction)

# %% [markdown]
# ### Objetivo
#
# Definir quais são os principais fatores que estão mais correlacionados com a satisfação de um passageiro e elaborar um modelo que consegue prever a satisfação de um passageiro.
#
# Para definir o nível de satisfação dos passageiros, utilizaremos as seguintes classes:
#
#    **0**: Neutro ou não satisfeito <br>
#    **1**: Satisfeito

# %%
#Importando as bibliotecas

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV, StratifiedKFold
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.activations import linear, relu, sigmoid
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# ## Importando os dados
#
# Importante salientar que estes dados são fornecidos já separados entre treino e teste. Mas para uma melhor análise dos dados, iremos concatenar todos em um único dataframe.

# %%
#Importando os dados de treino e teste
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
#Concatenando os dataframes de treino e test
df = pd.concat([train, test]).reset_index()

#Excluindo as colunas Unnamed, index e id que não serão relevantes para a análise
df = df.drop(columns=['Unnamed: 0', 'index', 'id'])

# %% [markdown]
# ## EDA (Análise exploratória de dados)

# %% [markdown]
# Aqui vamos explorar um pouco os dados a fim de entender melhor este dataset

# %%
#Olhando como é as 5 primeiras linhas do dataset
df.head()
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   13  Personal Travel  Eco Plus              460
# 1    Male  disloyal Customer   25  Business travel  Business              235
# 2  Female     Loyal Customer   26  Business travel  Business             1142
# 3  Female     Loyal Customer   25  Business travel  Business              562
# 4    Male     Loyal Customer   61  Business travel  Business              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# 1                       3              3  ...                       1
# 2                       2              2  ...                       5
# 3                       5              5  ...                       2
# 4                       3              3  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 3                 4                4
# 1                 1                 5                 3                1
# 2                 4                 3                 4                4
# 3                 2                 5                 3                1
# 4                 3                 4                 4                3
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 5            5                          25
# 1                 4            1                           1
# 2                 4            5                           0
# 3                 4            2                          11
# 4                 3            3                           0
#
#    Arrival Delay in Minutes             satisfaction
# 0                      18.0  neutral or dissatisfied
# 1                       6.0  neutral or dissatisfied
# 2                       0.0                satisfied
# 3                       9.0  neutral or dissatisfied
# 4                       0.0                satisfied
#
# [5 rows x 23 columns]

# %%
#Dimensões do dataset
df.shape
# Out:
# (129880, 23)

# %%
#Nome de todas as colunas
list(df.columns)
# Out:
# ['Gender',
#  'Customer Type',
#  'Age',
#  'Type of Travel',
#  'Class',
#  'Flight Distance',
#  'Inflight wifi service',
#  'Departure/Arrival time convenient',
#  'Ease of Online booking',
#  'Gate location',
#  'Food and drink',
#  'Online boarding',
#  'Seat comfort',
#  'Inflight entertainment',
#  'On-board service',
#  'Leg room service',
#  'Baggage handling',
#  'Checkin service',
#  'Inflight service',
#  'Cleanliness',
#  'Departure Delay in Minutes',
#  'Arrival Delay in Minutes',
#  'satisfaction']

# %%
#Tipo de cada variável
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 23 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             129880 non-null  object
#  1   Customer Type                      129880 non-null  object
#  2   Age                                129880 non-null  int64
#  3   Type of Travel                     129880 non-null  object
#  4   Class                              129880 non-null  object
#  5   Flight Distance                    129880 non-null  int64
#  6   Inflight wifi service              129880 non-null  int64
#  7   Departure/Arrival time convenient  129880 non-null  int64
#  8   Ease of Online booking             129880 non-null  int64
#  9   Gate location                      129880 non-null  int64
#  10  Food and drink                     129880 non-null  int64
#  11  Online boarding                    129880 non-null  int64
#  12  Seat comfort                       129880 non-null  int64
#  13  Inflight entertainment             129880 non-null  int64
#  14  On-board service                   129880 non-null  int64
#  15  Leg room service                   129880 non-null  int64
#  16  Baggage handling                   129880 non-null  int64
#  17  Checkin service                    129880 non-null  int64
#  18  Inflight service                   129880 non-null  int64
#  19  Cleanliness                        129880 non-null  int64
#  20  Departure Delay in Minutes         129880 non-null  int64
#  21  Arrival Delay in Minutes           129487 non-null  float64
#  22  satisfaction                       129880 non-null  object
# dtypes: float64(1), int64(17), object(5)
# memory usage: 22.8+ MB

# %%
# A feature Arrival Delay in Minutes possui 393 valores nulos
display(df.isnull().sum())
print(f"A feature Arrival Delay in Minutes possui {df['Arrival Delay in Minutes'].isnull().sum()} valores nulos")
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# satisfaction                           0
# dtype: int64
# A feature Arrival Delay in Minutes possui 393 valores nulos

# %%
#Olhando um pouco mais a fundo sobre a coluna com valores nulos
df['Arrival Delay in Minutes'].describe()
# Out:
# count    129487.000000
# mean         15.091129
# std          38.465650
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%          13.000000
# max        1584.000000
# Name: Arrival Delay in Minutes, dtype: float64

# %% [markdown]
# Apesar do valor máximo ser 1584 minutos, a mediana ainda é 0 e o valor da média é relativamente baixo, 15.09. Neste sentido, podemos concluir que a maior frequência de valores está em 0 minutos de atraso.
#
# Vamos verificar abaixo:

# %%
fig, ax = plt.subplots(figsize=(15, 6))
sns.histplot(data=df, x="Arrival Delay in Minutes", hue="Class", bins = 50)
# Out:
# <AxesSubplot:xlabel='Arrival Delay in Minutes', ylabel='Count'>

# %%
#Verificando as 10 ocorrências com maior frequência

display(df['Arrival Delay in Minutes'].value_counts()[:10])
# Out:
# 0.0     72753
# 1.0      2747
# 2.0      2587
# 3.0      2442
# 4.0      2373
# 5.0      2083
# 6.0      2021
# 7.0      1794
# 8.0      1751
# 9.0      1566
# 10.0     1466
# Name: Arrival Delay in Minutes, dtype: int64

# %%
#Excluindo linhas duplicadas, se houver
df.drop_duplicates(inplace=True)

# %%
# Dados não numéricos
df_num = df.loc[:, df.dtypes != object]
df_num
# Out:
#         Age  Flight Distance  Inflight wifi service  \
# 0        13              460                      3
# 1        25              235                      3
# 2        26             1142                      2
# 3        25              562                      2
# 4        61              214                      3
# ...     ...              ...                    ...
# 129875   34              526                      3
# 129876   23              646                      4
# 129877   17              828                      2
# 129878   14             1127                      3
# 129879   42              264                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 0                                       4                       3
# 1                                       2                       3
# 2                                       2                       2
# 3                                       5                       5
# 4                                       3                       3
# ...                                   ...                     ...
# 129875                                  3                       3
# 129876                                  4                       4
# 129877                                  5                       1
# 129878                                  3                       3
# 129879                                  5                       2
#
#         Gate location  Food and drink  Online boarding  Seat comfort  \
# 0                   1               5                3             5
# 1                   3               1                3             1
# 2                   2               5                5             5
# 3                   5               2                2             2
# 4                   3               4                5             5
# ...               ...             ...              ...           ...
# 129875              1               4                3             4
# 129876              4               4                4             4
# 129877              5               2                1             2
# 129878              3               4                4             4
# 129879              5               4                2             2
#
#         Inflight entertainment  On-board service  Leg room service  \
# 0                            5                 4                 3
# 1                            1                 1                 5
# 2                            5                 4                 3
# 3                            2                 2                 5
# 4                            3                 3                 4
# ...                        ...               ...               ...
# 129875                       4                 3                 2
# 129876                       4                 4                 5
# 129877                       2                 4                 3
# 129878                       4                 3                 2
# 129879                       1                 1                 2
#
#         Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                      4                4                 5            5
# 1                      3                1                 4            1
# 2                      4                4                 4            5
# 3                      3                1                 4            2
# 4                      4                3                 3            3
# ...                  ...              ...               ...          ...
# 129875                 4                4                 5            4
# 129876                 5                5                 5            4
# 129877                 4                5                 4            2
# 129878                 5                4                 5            4
# 129879                 1                1                 1            1
#
#         Departure Delay in Minutes  Arrival Delay in Minutes
# 0                               25                      18.0
# 1                                1                       6.0
# 2                                0                       0.0
# 3                               11                       9.0
# 4                                0                       0.0
# ...                            ...                       ...
# 129875                           0                       0.0
# 129876                           0                       0.0
# 129877                           0                       0.0
# 129878                           0                       0.0
# 129879                           0                       0.0
#
# [129880 rows x 18 columns]

# %%
# Dados não numéricos
df_cat = df.loc[:, df.dtypes == object]
df_cat
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 129875    Male  disloyal Customer  Business travel  Business
# 129876    Male     Loyal Customer  Business travel  Business
# 129877  Female     Loyal Customer  Personal Travel       Eco
# 129878    Male     Loyal Customer  Business travel  Business
# 129879  Female     Loyal Customer  Personal Travel       Eco
#
#                    satisfaction
# 0       neutral or dissatisfied
# 1       neutral or dissatisfied
# 2                     satisfied
# 3       neutral or dissatisfied
# 4                     satisfied
# ...                         ...
# 129875  neutral or dissatisfied
# 129876                satisfied
# 129877  neutral or dissatisfied
# 129878                satisfied
# 129879  neutral or dissatisfied
#
# [129880 rows x 5 columns]

# %%
df.describe().apply(lambda x: round(x, 1))
# Out:
#             Age  Flight Distance  Inflight wifi service  \
# count  129880.0         129880.0               129880.0
# mean       39.4           1190.3                    2.7
# std        15.1            997.5                    1.3
# min         7.0             31.0                    0.0
# 25%        27.0            414.0                    2.0
# 50%        40.0            844.0                    3.0
# 75%        51.0           1744.0                    4.0
# max        85.0           4983.0                    5.0
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                           129880.0                129880.0
# mean                                 3.1                     2.8
# std                                  1.5                     1.4
# min                                  0.0                     0.0
# 25%                                  2.0                     2.0
# 50%                                  3.0                     3.0
# 75%                                  4.0                     4.0
# max                                  5.0                     5.0
#
#        Gate location  Food and drink  Online boarding  Seat comfort  \
# count       129880.0        129880.0         129880.0      129880.0
# mean             3.0             3.2              3.3           3.4
# std              1.3             1.3              1.4           1.3
# min              0.0             0.0              0.0           0.0
# 25%              2.0             2.0              2.0           2.0
# 50%              3.0             3.0              3.0           4.0
# 75%              4.0             4.0              4.0           5.0
# max              5.0             5.0              5.0           5.0
#
#        Inflight entertainment  On-board service  Leg room service  \
# count                129880.0          129880.0          129880.0
# mean                      3.4               3.4               3.4
# std                       1.3               1.3               1.3
# min                       0.0               0.0               0.0
# 25%                       2.0               2.0               2.0
# 50%                       4.0               4.0               4.0
# 75%                       4.0               4.0               4.0
# max                       5.0               5.0               5.0
#
#        Baggage handling  Checkin service  Inflight service  Cleanliness  \
# count          129880.0         129880.0          129880.0     129880.0
# mean                3.6              3.3               3.6          3.3
# std                 1.2              1.3               1.2          1.3
# min                 1.0              0.0               0.0          0.0
# 25%                 3.0              3.0               3.0          2.0
# 50%                 4.0              3.0               4.0          3.0
# 75%                 5.0              4.0               5.0          4.0
# max                 5.0              5.0               5.0          5.0
#
#        Departure Delay in Minutes  Arrival Delay in Minutes
# count                    129880.0                  129487.0
# mean                         14.7                      15.1
# std                          38.1                      38.5
# min                           0.0                       0.0
# 25%                           0.0                       0.0
# 50%                           0.0                       0.0
# 75%                          12.0                      13.0
# max                        1592.0                    1584.0

# %%
df.satisfaction.value_counts()
# Out:
# neutral or dissatisfied    73452
# satisfied                  56428
# Name: satisfaction, dtype: int64

# %%
#Substituindo os valores do nosso target para valores numéricos
satisfaction_map = {
    'neutral or dissatisfied': 0,
    'satisfied': 1
}
df.satisfaction = df.satisfaction.map(satisfaction_map)

# %%
#Distribuição do nosso target
df.satisfaction.value_counts()
# Out:
# 0    73452
# 1    56428
# Name: satisfaction, dtype: int64

# %% [markdown]
# ## Distribuição de Valores

# %%
def divide_col(df_col, n):
    '''
    Dividir as colunas do dataset em blocos de tamanho n
    '''
    
    for i in range(0, len(df_col), n):
        yield df_col[i:i + n]

# %%
size_col = len(train.columns)
features = list(train.columns)

cols = list(divide_col(features, 5))

for f in features:
    print(f"Distribuição - {f}")
    for block in cols:
        display(sns.pairplot(data=df,
                             y_vars=f,
                             x_vars=block))
        plt.show()
# Out:
# Distribuição - Gender
# Distribuição - Customer Type
# Distribuição - Age
# Distribuição - Type of Travel
# Distribuição - Class
# Distribuição - Flight Distance
# Distribuição - Inflight wifi service
# Distribuição - Departure/Arrival time convenient
# Distribuição - Ease of Online booking
# Distribuição - Gate location
# Distribuição - Food and drink
# Distribuição - Online boarding
# Distribuição - Seat comfort
# Distribuição - Inflight entertainment
# Distribuição - On-board service
# Distribuição - Leg room service
# Distribuição - Baggage handling
# Distribuição - Checkin service
# Distribuição - Inflight service
# Distribuição - Cleanliness
# Distribuição - Departure Delay in Minutes
# Distribuição - Arrival Delay in Minutes
# Distribuição - satisfaction

# %%
#Proporção entre as Classes das passagens

data = df['Class'].value_counts()
labels = df['Class'].unique()

#Definindo as cores
colors = sns.color_palette('rocket')[3:6]

fig, ax = plt.subplots(figsize=(8, 6))


#Criando gráfico de pizza
plt.pie(data, labels = labels, colors = colors, autopct='%.2f%%')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)
plt.show()

# %%
#Probabilidade de um cliente satisfeito de acordo com a Classe da passagem e de acordo com as outras variáveis categóricas

col_categ = df_cat.drop(columns='satisfaction').columns
for categ in col_categ:
    display(df.groupby(['Class',categ])[['satisfaction']].mean())
# Out:
#                  satisfaction
# Class    Gender
# Business Female      0.690913
#          Male        0.697997
# Eco      Female      0.185339
#          Male        0.190090
# Eco Plus Female      0.235602
#          Male        0.258493
#                             satisfaction
# Class    Customer Type
# Business Loyal Customer         0.746358
#          disloyal Customer      0.396707
# Eco      Loyal Customer         0.200963
#          disloyal Customer      0.144125
# Eco Plus Loyal Customer         0.264360
#          disloyal Customer      0.079781
#                           satisfaction
# Class    Type of Travel
# Business Business travel      0.720376
#          Personal Travel      0.117097
# Eco      Business travel      0.299478
#          Personal Travel      0.101954
# Eco Plus Business travel      0.392697
#          Personal Travel      0.087381
#                    satisfaction
# Class    Class
# Business Business      0.694434
# Eco      Eco           0.187673
# Eco Plus Eco Plus      0.246414

# %% [markdown]
# Dos dados acima, podemos verificar que os clientes da classe business estão muito mais satisfeitos do que da Economy e Economy Plus. Além disso, dentre os tipos de viagens e os tipos de clientes, os clientes que viajam a negócios e são clientes recorrentes tem maior probabilidade de ficar satisfeito com a viagem que clientes que viajam por razões pessoais e/ou não são clientes recorrentes.
#
# Por fim, cabe ressaltar que o sexo não interfere no nível de satisfação do cliente. Isso é um bom indicador que não há diferenças no serviço com relação ao sexo, assim, o conjunto de qualidades da companhia aerea consegue atingir igualmente ambos os gêneros.

# %%
#Distribuição da frequência das variáveis numéricas

for col in df_num:

    sns.histplot(data=df_num, x=col, kde=True).set_title(f"Distribuição da variável {col}")
    plt.show()

# %%
#Distribuição de satisfação por Classe de passagem

fig = plt.figure(figsize=(10,7))
ax = fig.add_axes([0,0,1,1])
sns.countplot(data = df, x = 'Class', hue = 'satisfaction', palette='crest')
plt.title("Distribuição de satisfação por Classe de passagem")
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', borderaxespad=0)

# %%
print('Distribuição por faixa etária\n')

print("0-15 anos:\t", df[df["Age"] <= 15].shape[0])

print("15-30 anos:\t", df[(df["Age"] > 15) & (df["Age"] <= 30)].shape[0])

print("30-45 anos:\t", df[(df["Age"] > 30) & (df["Age"] <= 45)].shape[0])

print("45+ anos:\t", df[df["Age"] > 45].shape[0])
# Out:
# Distribuição por faixa etária
#
# 0-15 anos:	 7466
# 15-30 anos:	 33414
# 30-45 anos:	 41482
# 45+ anos:	 47518

# %%
print('Distribuição de sexo por faixa etária\n')

print("0-15 anos:\n", df[df["Age"] <= 15]["Gender"].value_counts(normalize=True), "\n")

print("15-30 anos:\n",df[(df["Age"] > 15) & (df["Age"] <= 30)]["Gender"].value_counts(normalize=True), "\n")

print("30-45 anos:\n",df[(df["Age"] > 30) & (df["Age"] <= 45)]["Gender"].value_counts(normalize=True), "\n")

print("45+ anos:\n",df[df["Age"] > 45]["Gender"].value_counts(normalize=True), "\n")
# Out:
# Distribuição de sexo por faixa etária
#
# 0-15 anos:
#  Female    0.504152
# Male      0.495848
# Name: Gender, dtype: float64
#
# 15-30 anos:
#  Female    0.521099
# Male      0.478901
# Name: Gender, dtype: float64
#
# 30-45 anos:
#  Female    0.502507
# Male      0.497493
# Name: Gender, dtype: float64
#
# 45+ anos:
#  Female    0.502504
# Male      0.497496
# Name: Gender, dtype: float64

# %%
print('Distribuição da satisfação por faixa etária\n')
print("0-15 anos:\n", df[df["Age"] <= 15]["satisfaction"].value_counts(normalize=True), "\n")
print("15-30 anos:\n",df[(df["Age"] > 15) & (df["Age"] <= 30)]["satisfaction"].value_counts(normalize=True), "\n")
print("30-45 anos:\n",df[(df["Age"] > 30) & (df["Age"] <= 45)]["satisfaction"].value_counts(normalize=True), "\n")
print("45+ anos:\n",df[df["Age"] > 45]["satisfaction"].value_counts(normalize=True), "\n")
# Out:
# Distribuição da satisfação por faixa etária
#
# 0-15 anos:
#  0    0.853737
# 1    0.146263
# Name: satisfaction, dtype: float64
#
# 15-30 anos:
#  0    0.656372
# 1    0.343628
# Name: satisfaction, dtype: float64
#
# 30-45 anos:
#  0    0.511933
# 1    0.488067
# Name: satisfaction, dtype: float64
#
# 45+ anos:
#  0    0.503178
# 1    0.496822
# Name: satisfaction, dtype: float64

# %% [markdown]
# ## Correlação entre as features

# %%
plt.figure(figsize=(20, 15))

sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
df.corr()["satisfaction"].sort_values()
# Out:
# Arrival Delay in Minutes            -0.058275
# Departure/Arrival time convenient   -0.054270
# Departure Delay in Minutes          -0.050740
# Gate location                       -0.002793
# Age                                  0.134091
# Ease of Online booking               0.168877
# Food and drink                       0.211340
# Checkin service                      0.237252
# Inflight service                     0.244918
# Baggage handling                     0.248680
# Inflight wifi service                0.283460
# Flight Distance                      0.298085
# Cleanliness                          0.307035
# Leg room service                     0.312424
# On-board service                     0.322205
# Seat comfort                         0.348829
# Inflight entertainment               0.398234
# Online boarding                      0.501749
# satisfaction                         1.000000
# Name: satisfaction, dtype: float64

# %% [markdown]
# ## Separando novamente o dataset entre treino e teste

# %%
X = df.drop(columns='satisfaction')
y = df['satisfaction']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# ## Outliers

# %%
train = X_train
train['satisfaction'] = y_train
train
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 27875     Male     Loyal Customer   40  Business travel  Business
# 38437   Female     Loyal Customer   29  Business travel  Business
# 120302  Female  disloyal Customer   45  Business travel  Business
# 46094     Male     Loyal Customer   52  Business travel  Business
# 56431   Female     Loyal Customer   53  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 120752  Female     Loyal Customer   49  Business travel  Business
# 10445   Female     Loyal Customer   55  Personal Travel       Eco
# 111587    Male     Loyal Customer   30  Business travel  Business
# 58592   Female     Loyal Customer   44  Business travel  Business
# 15659   Female     Loyal Customer   31  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 27875              3292                      5
# 38437              2389                      5
# 120302             1276                      2
# 46094              2150                      5
# 56431              3310                      1
# ...                 ...                    ...
# 120752             1072                      2
# 10445               109                      2
# 111587             2525                      0
# 58592              1440                      5
# 15659               862                      2
#
#         Departure/Arrival time convenient  Ease of Online booking  \
# 27875                                   5                       5
# 38437                                   4                       5
# 120302                                  2                       2
# 46094                                   5                       5
# 56431                                   1                       1
# ...                                   ...                     ...
# 120752                                  2                       4
# 10445                                   5                       0
# 111587                                  0                       0
# 58592                                   5                       5
# 15659                                   4                       2
#
#         Gate location  ...  Inflight entertainment  On-board service  \
# 27875               5  ...                       4                 4
# 38437               5  ...                       5                 3
# 120302              3  ...                       5                 5
# 46094               5  ...                       5                 5
# 56431               1  ...                       5                 5
# ...               ...  ...                     ...               ...
# 120752              2  ...                       4                 4
# 10445               5  ...                       4                 4
# 111587              2  ...                       4                 5
# 58592               5  ...                       4                 4
# 15659               2  ...                       5                 5
#
#         Leg room service  Baggage handling  Checkin service  Inflight service  \
# 27875                  4                 4                4                 4
# 38437                  3                 4                5                 5
# 120302                 4                 5                4                 4
# 46094                  5                 5                5                 5
# 56431                  4                 5                3                 5
# ...                  ...               ...              ...               ...
# 120752                 4                 4                4                 4
# 10445                  0                 2                5                 4
# 111587                 3                 3                5                 5
# 58592                  4                 4                5                 4
# 15659                  3                 4                3                 5
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes  \
# 27875             3                           0                       0.0
# 38437             5                           9                       0.0
# 120302            5                           8                       0.0
# 46094             3                          46                      42.0
# 56431             4                           1                       0.0
# ...             ...                         ...                       ...
# 120752            4                          11                       4.0
# 10445             4                           0                       0.0
# 111587            4                          14                      22.0
# 58592             4                          51                      45.0
# 15659             5                           0                       0.0
#
#         satisfaction
# 27875              1
# 38437              1
# 120302             0
# 46094              1
# 56431              1
# ...              ...
# 120752             1
# 10445              0
# 111587             1
# 58592              1
# 15659              0
#
# [90916 rows x 23 columns]

# %%
# Cálculo do intervalo interquartil
Q1 = train.quantile(0.25)
Q3 = train.quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# Age                                    24.0
# Flight Distance                      1330.0
# Inflight wifi service                   2.0
# Departure/Arrival time convenient       2.0
# Ease of Online booking                  2.0
# Gate location                           2.0
# Food and drink                          2.0
# Online boarding                         2.0
# Seat comfort                            3.0
# Inflight entertainment                  2.0
# On-board service                        2.0
# Leg room service                        2.0
# Baggage handling                        2.0
# Checkin service                         1.0
# Inflight service                        2.0
# Cleanliness                             2.0
# Departure Delay in Minutes             12.0
# Arrival Delay in Minutes               13.0
# satisfaction                            1.0
# dtype: float64

# %%
import warnings
warnings.filterwarnings("ignore")
#Removendo outliers
train_without_outliers = train[~((train < (Q1 - 1.5 * IQR)) |(train > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
train_without_outliers.shape
# Out:
# (65496, 23)

# %% [markdown]
# Com a remoção de outliers, perdemos 25.420 linhas de informações no geral. Neste sentido, em vez de remover todos os outliers, podemos remover apenas de algumas colunas onde há uma grande amplitude.
#
# Conforme abaixo, as features com maior amplitude são:
#
# Flight Distance, Departure Delay in Minutes, Arrival Delay in Minutes

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight wifi service  \
# count  129880.000000    129880.000000          129880.000000
# mean       39.427957      1190.316392               2.728696
# std        15.119360       997.452477               1.329340
# min         7.000000        31.000000               0.000000
# 25%        27.000000       414.000000               2.000000
# 50%        40.000000       844.000000               3.000000
# 75%        51.000000      1744.000000               4.000000
# max        85.000000      4983.000000               5.000000
#
#        Departure/Arrival time convenient  Ease of Online booking  \
# count                      129880.000000           129880.000000
# mean                            3.057599                2.756876
# std                             1.526741                1.401740
# min                             0.000000                0.000000
# 25%                             2.000000                2.000000
# 50%                             3.000000                3.000000
# 75%                             4.000000                4.000000
# max                             5.000000                5.000000
#
#        Gate location  Food and drink  Online boarding   Seat comfort  \
# count  129880.000000   129880.000000    129880.000000  129880.000000
# mean        2.976925        3.204774         3.252633       3.441361
# std         1.278520        1.329933         1.350719       1.319289
# min         0.000000        0.000000         0.000000       0.000000
# 25%         2.000000        2.000000         2.000000       2.000000
# 50%         3.000000        3.000000         3.000000       4.000000
# 75%         4.000000        4.000000         4.000000       5.000000
# max         5.000000        5.000000         5.000000       5.000000
#
#        Inflight entertainment  On-board service  Leg room service  \
# count           129880.000000     129880.000000     129880.000000
# mean                 3.358077          3.383023          3.350878
# std                  1.334049          1.287099          1.316252
# min                  0.000000          0.000000          0.000000
# 25%                  2.000000          2.000000          2.000000
# 50%                  4.000000          4.000000          4.000000
# 75%                  4.000000          4.000000          4.000000
# max                  5.000000          5.000000          5.000000
#
#        Baggage handling  Checkin service  Inflight service    Cleanliness  \
# count     129880.000000    129880.000000     129880.000000  129880.000000
# mean           3.632114         3.306267          3.642193       3.286326
# std            1.180025         1.266185          1.176669       1.313682
# min            1.000000         0.000000          0.000000       0.000000
# 25%            3.000000         3.000000          3.000000       2.000000
# 50%            4.000000         3.000000          4.000000       3.000000
# 75%            5.000000         4.000000          5.000000       4.000000
# max            5.000000         5.000000          5.000000       5.000000
#
#        Departure Delay in Minutes  Arrival Delay in Minutes   satisfaction
# count               129880.000000             129487.000000  129880.000000
# mean                    14.713713                 15.091129       0.434463
# std                     38.071126                 38.465650       0.495688
# min                      0.000000                  0.000000       0.000000
# 25%                      0.000000                  0.000000       0.000000
# 50%                      0.000000                  0.000000       0.000000
# 75%                     12.000000                 13.000000       1.000000
# max                   1592.000000               1584.000000       1.000000

# %%
remove_outliers = ['Flight Distance','Departure Delay in Minutes', 'Arrival Delay in Minutes']

for col in train:
    if col in remove_outliers:
        q1 = train[col].quantile(0.25)
        q3 = train[col].quantile(0.75)
        IQR = q3 - q1
        
        lower_limit = q1 - 1.5 * IQR
        upper_limit = q3 + 1.5 * IQR
        train = train[train[col] >= lower_limit]
        train = train[train[col] <= upper_limit]

# %%
train.shape
# Out:
# (65739, 23)

# %% [markdown]
# Conforme acima, houve mais remoções, mas conseguimos reter um pouco mais de informação.

# %%
#Separando novamente em X_train e y_train
X_train = train.drop(columns="satisfaction")
y_train = train['satisfaction']

# %% [markdown]
# # Modelos

# %% [markdown]
# Os processos a seguir estão divididos nas seguintes etapas:
#     1 - Pré-processamento dos dados em uma pipeline
#     2 - Treinar um modelo de regressão logística como baseline e verificar as métricas
#     3 - Treinar modelos de Machine Learning classicos e verificar o desempenho de cada um
#     4 - Treino de um modelo de rede neural.

# %%
#Separar os nomes das features numéricas e categóricas
num_feat = list(df_num.columns)
cat_feat = list(col_categ)

# %%
#Instanciando um pre processador que preenche nulos com valores da mediana, uma vez que verificamos a presença de outliers
#Normaliza com standard scaler, as variáveis numéricas e transforma as variáveis categóricas em dummies.
num_transformer = Pipeline(
    steps=[
        ('imputer', SimpleImputer(strategy="median")),
        ('scaler', StandardScaler())
    ]
)

cat_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ("num", num_transformer, num_feat),
        ("cat", cat_transformer, cat_feat),
    ]
)

# %%
#Treinar o nosso modelo de regressão logística, que servirá como baseline
pipe_logit = Pipeline([("preprocessor", preprocessor),
                       ("logit", LogisticRegression())])

pipe_logit.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Flight Distance',
#                                                    'Inflight wifi service',
#                                                    'Departure/Arrival time '
#                                                    'convenient',
#                                                    'Ease of Online booking',
#                                                    'Gate location',
#                                                    'Food and drink',
#                                                    'Online boarding',
#                                                    'Seat comfort',
#                                                    'Inflight entertainment',
#                                                    'On-board service',
#                                                    'Leg room service',
#                                                    'Baggage handling',
#                                                    'Checkin service',
#                                                    'Inflight service',
#                                                    'Cleanliness',
#                                                    'Departure Delay in Minutes',
#                                                    'Arrival Delay in Minutes']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Gender', 'Customer Type',
#                                                    'Type of Travel',
#                                                    'Class'])])),
#                 ('logit', LogisticRegression())])

# %%
def clf_metrics(modelo, X, y_true, label):
    '''
    Função para mostrar as métricas de avaliação de um modelo pelo classification report
    '''
    print(f"\nMétricas de avaliação de {label}:\n")    
    y_pred = modelo.predict(X)
    print(classification_report(y_true, y_pred))

# %%
clf_metrics(pipe_logit, X_train, y_train, "treino")
print("#"*80)
clf_metrics(pipe_logit, X_test, y_test, "teste")
# Out:
# Métricas de avaliação de treino:
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88     35927
#            1       0.87      0.83      0.85     29812
#
#     accuracy                           0.87     65739
#    macro avg       0.87      0.87      0.87     65739
# weighted avg       0.87      0.87      0.87     65739
#
# ################################################################################
#
# Métricas de avaliação de teste:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.92      0.87     22036
#            1       0.88      0.75      0.81     16928
#
#     accuracy                           0.85     38964
#    macro avg       0.85      0.83      0.84     38964
# weighted avg       0.85      0.85      0.84     38964

# %%
def clf_metrics_com_return(modelo, X, y_true, label):
  
   
    y_pred = modelo.predict(X)
    
    return classification_report(y_true, y_pred, output_dict=True)

# %%
def experimentos_ciclo_de_modelagem(dict_pipes,
                                    print_progress = False):
    
    resultado_experimentos = {"estimador" : [],
                              "f1_treino" : [],
                              "f1_teste" : []}

    for label, pipe in dict_pipes.items():

        if print_progress:
            print("\n")
            print("="*80)
            print(f"Estimador: {label}".center(80))
            print("(com hiperparâmetros default)".center(80))
            print("="*80)
            print("\n")

        # ================================

        pipe.fit(X_train, y_train)

        # ================================
        # Passo 2

        dict_metricas_treino = clf_metrics_com_return(pipe, X_train, y_train, "treino")

        if print_progress:
            print("#"*80)

        dict_metricas_teste = clf_metrics_com_return(pipe, X_test, y_test, "teste")

        # pegar as métricas
        f1_treino = dict_metricas_treino["weighted avg"]["f1-score"]
        f1_teste = dict_metricas_teste["weighted avg"]["f1-score"]

        # ================================
        # guardando os resultados do experimento

        resultado_experimentos["estimador"].append(label)
        resultado_experimentos["f1_treino"].append(f1_treino)
        resultado_experimentos["f1_teste"].append(f1_teste)


    df_results = pd.DataFrame(resultado_experimentos)

    df_results["gap"] = (df_results["f1_treino"] - df_results["f1_teste"]).apply(lambda x: x if x > 0 else np.inf)

    df_results = df_results.sort_values("f1_teste", ascending=False).sort_values("gap")

    return df_results

# %%
pipe_logit = Pipeline([("preprocessor", preprocessor),
                       ("logit", LogisticRegression(random_state=42))])

pipe_rf = Pipeline([("preprocessor", preprocessor),
                    ("rf", RandomForestClassifier(random_state=42))])

pipe_dt = Pipeline([("preprocessor", preprocessor),
                    ("dt", DecisionTreeClassifier(random_state=42))])

pipe_svm = Pipeline([("preprocessor", preprocessor),
                     ("svm", SVC(random_state=42))])

pipe_xbgoost = Pipeline([("preprocessor", preprocessor),
                         ("xgboost", XGBClassifier(random_state=42))])

pipe_lgbm = Pipeline([("preprocessor", preprocessor),
                      ("lgbm", LGBMClassifier(random_state=42))])

pipe_knn = Pipeline([("preprocessor", preprocessor),
                     ("knn", KNeighborsClassifier())])

# =======================================

dict_pipes = {"logit" : pipe_logit,
              "random_forest" : pipe_rf,
              "decision_tree" : pipe_dt,
              "svm" : pipe_svm,
              "xgboost" : pipe_xbgoost,
              "lgbm" : pipe_lgbm,
              "knn" : pipe_knn}

# =======================================

df_results = experimentos_ciclo_de_modelagem(dict_pipes,
                                             print_progress = False)

df_results
# Out:
#        estimador  f1_treino  f1_teste       gap
# 5           lgbm   0.964232  0.962547  0.001685
# 4        xgboost   0.976976  0.962519  0.014458
# 0          logit   0.869408  0.843911  0.025497
# 6            knn   0.943274  0.909111  0.034163
# 1  random_forest   0.999985  0.960456  0.039529
# 2  decision_tree   1.000000  0.940570  0.059430
# 3            svm   0.953059  0.845397  0.107662

# %% [markdown]
# Dos modelos acima, o lightgbm e o xgboost apresentaram f1 score melhores, além disso o gap entre o f1 de treino e de teste do lgbm foi bem baixo.
#
# Ademais, podemos notar um pouco de overfit no random forest e na decision tree. Isso pode ter acontecido principalmente em razão de não ter sido definido nenhum hiperparâmetro ao instanciar estes modelos.

# %% [markdown]
# Para verificar se conseguimos melhorar o random forest, vamos utilizar o random search para a otimização dos hiperparâmetros.

# %% [markdown]
# ### Random Forest com otimização de hiperparâmetros

# %%
# pipeline
pipe_rf = Pipeline([("preprocessor", preprocessor),
                    ("rf", RandomForestClassifier(n_jobs=-1, random_state=42))])

# espaço de hiperparâmetros 
# (esta definição vem do conhecimento que temos do método e de seus hiperparâmetros)
params_distributions = {"rf__n_estimators" : np.arange(100, 1501, 1), 
                        "rf__max_depth" : np.arange(2, 9, 1)}

# estratégia de cross validation 
splitter = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# montamos o objeto do random search
rand_grid_rf = RandomizedSearchCV(pipe_rf, 
                                  params_distributions, 
                                  n_iter=20,
                                  cv=splitter,
                                  scoring="f1_weighted",
                                  verbose=10,
                                  n_jobs=-1,
                                  random_state=42,
                                  return_train_score=True)

rand_grid_rf.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# RandomizedSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessor',
#                                               ColumnTransformer(transformers=[('num',
#                                                                                Pipeline(steps=[('imputer',
#                                                                                                 SimpleImputer(strategy='median')),
#                                                                                                ('scaler',
#                                                                                                 StandardScaler())]),
#                                                                                ['Age',
#                                                                                 'Flight '
#                                                                                 'Distance',
#                                                                                 'Inflight '
#                                                                                 'wifi '
#                                                                                 'service',
#                                                                                 'Departure/Arrival '
#                                                                                 'time '
#                                                                                 'convenient',
#                                                                                 'Ease '
#                                                                                 'of...
#                                                                                OneHotEncoder(handle_unknown='ignore'),
#                                                                                ['Gender',
#                                                                                 'Customer '
#                                                                                 'Type',
#                                                                                 'Type '
#                                                                                 'of '
#                                                                                 'Travel',
#                                                                                 'Class'])])),
#                                              ('rf',
#                                               RandomForestClassifier(n_jobs=-1,
#                                                                      random_state=42))]),
#                    n_iter=20, n_jobs=-1,
#                    param_distributions={'rf__max_depth': array([2, 3, 4, 5, 6, 7, 8]),
#                                         'rf__n_estimators': array([ 100,  101,  102, ..., 1498, 1499, 1500])},
#                    random_state=42, return_train_score=True,
#                    scoring='f1_weighted', verbose=10)

# %%
rand_grid_rf.best_params_
# Out:
# {'rf__n_estimators': 1417, 'rf__max_depth': 7}

# %%
pipe_rf = Pipeline([("preprocessor", preprocessor),
                    ("rf", RandomForestClassifier(random_state=42))]).set_params(**{'rf__n_estimators': 1417,
                                                                                    'rf__max_depth': 7})

pipe_rf.fit(X_train, y_train)

# ================================
# Passo 2

clf_metrics(pipe_rf, X_train, y_train, "treino")
print("#"*80)
clf_metrics(pipe_rf, X_test, y_test, "teste")
# Out:
# Métricas de avaliação de treino:
#
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94     35927
#            1       0.94      0.91      0.93     29812
#
#     accuracy                           0.93     65739
#    macro avg       0.93      0.93      0.93     65739
# weighted avg       0.93      0.93      0.93     65739
#
# ################################################################################
#
# Métricas de avaliação de teste:
#
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     22036
#            1       0.93      0.92      0.92     16928
#
#     accuracy                           0.93     38964
#    macro avg       0.93      0.93      0.93     38964
# weighted avg       0.93      0.93      0.93     38964

# %% [markdown]
# Com a otimização de hiperparâmetro conseguimos resolver o problema de overfitting e ainda trazer métricas um pouco mais próximas do xgboost

# %%
df_feat_import = pd.DataFrame(pipe_rf['rf'].feature_importances_, index=preprocessor.get_feature_names_out(), columns=['feature importance'])
df_feat_import.sort_values(by="feature importance", ascending=False)
# Out:
#                                         feature importance
# num__Online boarding                              0.205206
# num__Inflight wifi service                        0.148137
# cat__Class_Business                               0.088266
# cat__Type of Travel_Personal Travel               0.087356
# cat__Type of Travel_Business travel               0.076865
# num__Inflight entertainment                       0.065607
# cat__Class_Eco                                    0.043551
# num__Seat comfort                                 0.042760
# num__Ease of Online booking                       0.040346
# cat__Customer Type_Loyal Customer                 0.031764
# num__Leg room service                             0.030837
# cat__Customer Type_disloyal Customer              0.030752
# num__On-board service                             0.022147
# num__Cleanliness                                  0.018105
# num__Checkin service                              0.011678
# num__Inflight service                             0.011446
# num__Baggage handling                             0.011422
# num__Flight Distance                              0.008518
# num__Age                                          0.008476
# num__Departure/Arrival time convenient            0.005522
# num__Food and drink                               0.004245
# num__Gate location                                0.003594
# cat__Class_Eco Plus                               0.000802
# num__Arrival Delay in Minutes                     0.000795
# cat__Gender_Male                                  0.000791
# cat__Gender_Female                                0.000788
# num__Departure Delay in Minutes                   0.000224

# %% [markdown]
# # Redes neurais

# %% [markdown]
# Por fim, vamos ver se uma rede neural pode apresentar resultados tão bons.

# %%
tf.random.set_seed(42) 
model = Sequential(
    [
        Dense(27, activation = 'relu', input_shape=(27,),  name = "L1"),
        Dense(40, activation = 'relu',   name = "L2"),
        Dense(30, activation = 'relu',   name = "L3"),
        Dense(1, activation = 'sigmoid', name = "L4")
    ]
)

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.01),
)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  L1 (Dense)                  (None, 27)                756
#
#  L2 (Dense)                  (None, 40)                1120
#
#  L3 (Dense)                  (None, 30)                1230
#
#  L4 (Dense)                  (None, 1)                 31
#
# =================================================================
# Total params: 3,137
# Trainable params: 3,137
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stop = EarlyStopping(monitor = 'val_loss',
                           min_delta=0.001,
                           patience = 30,
                           verbose = 1,
                           mode = 'auto')

# %%
model_es = KerasClassifier(model=model, verbose=1, epochs=100, validation_split = 0.3, callbacks=[early_stop])

# %%
pipe_nn = Pipeline([("preprocessor", preprocessor),
                    ("nn", model_es)])

# %%
pipe_nn.fit(X_train, y_train)
# Out:
# Epoch 1/100
# 1439/1439 [==============================] - 4s 2ms/step - loss: 0.1876 - val_loss: 0.1424
# Epoch 2/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1336 - val_loss: 0.1253
# Epoch 3/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1239 - val_loss: 0.1254
# Epoch 4/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1171 - val_loss: 0.1178
# Epoch 5/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1136 - val_loss: 0.1186
# Epoch 6/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1102 - val_loss: 0.1130
# Epoch 7/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1083 - val_loss: 0.1084
# Epoch 8/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1053 - val_loss: 0.1118
# Epoch 9/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1046 - val_loss: 0.1072
# Epoch 10/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1035 - val_loss: 0.1107
# Epoch 11/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1003 - val_loss: 0.1082
# Epoch 12/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.1008 - val_loss: 0.1028
# Epoch 13/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0974 - val_loss: 0.1084
# Epoch 14/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0963 - val_loss: 0.1035
# Epoch 15/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0956 - val_loss: 0.1012
# Epoch 16/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0987 - val_loss: 0.1023
# Epoch 17/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0950 - val_loss: 0.0984
# Epoch 18/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0965 - val_loss: 0.1040
# Epoch 19/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0946 - val_loss: 0.0987
# Epoch 20/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0923 - val_loss: 0.1056
# Epoch 21/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0952 - val_loss: 0.0983
# Epoch 22/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0930 - val_loss: 0.0979
# Epoch 23/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0923 - val_loss: 0.1066
# Epoch 24/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0945 - val_loss: 0.1019
# Epoch 25/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0924 - val_loss: 0.1063
# Epoch 26/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0928 - val_loss: 0.1033
# Epoch 27/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0925 - val_loss: 0.1026
# Epoch 28/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0903 - val_loss: 0.1020
# Epoch 29/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0908 - val_loss: 0.1065
# Epoch 30/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0891 - val_loss: 0.1023
# Epoch 31/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0917 - val_loss: 0.1021
# Epoch 32/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0893 - val_loss: 0.1044
# Epoch 33/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0901 - val_loss: 0.1122
# Epoch 34/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0896 - val_loss: 0.1070
# Epoch 35/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0890 - val_loss: 0.0986
# Epoch 36/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0886 - val_loss: 0.1149
# Epoch 37/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0903 - val_loss: 0.1073
# Epoch 38/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0871 - val_loss: 0.1009
# Epoch 39/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0882 - val_loss: 0.0995
# Epoch 40/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0913 - val_loss: 0.1073
# Epoch 41/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0867 - val_loss: 0.1169
# Epoch 42/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0900 - val_loss: 0.1025
# Epoch 43/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0864 - val_loss: 0.0973
# Epoch 44/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0884 - val_loss: 0.1084
# Epoch 45/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0941 - val_loss: 0.1018
# Epoch 46/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0860 - val_loss: 0.1128
# Epoch 47/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0872 - val_loss: 0.1021
# Epoch 48/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0858 - val_loss: 0.1309
# Epoch 49/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0917 - val_loss: 0.1051
# Epoch 50/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0875 - val_loss: 0.1007
# Epoch 51/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0852 - val_loss: 0.1160
# Epoch 52/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0855 - val_loss: 0.1067
# Epoch 53/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0879 - val_loss: 0.1182
# Epoch 54/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0867 - val_loss: 0.1054
# Epoch 55/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0900 - val_loss: 0.1019
# Epoch 56/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0872 - val_loss: 0.1190
# Epoch 57/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0888 - val_loss: 0.1015
# Epoch 58/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0896 - val_loss: 0.1149
# Epoch 59/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0857 - val_loss: 0.1182
# Epoch 60/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0840 - val_loss: 0.1071
# Epoch 61/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0839 - val_loss: 0.1080
# Epoch 62/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0912 - val_loss: 0.1089
# Epoch 63/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0874 - val_loss: 0.1063
# Epoch 64/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0828 - val_loss: 0.1029
# Epoch 65/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0834 - val_loss: 0.1031
# Epoch 66/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0838 - val_loss: 0.1056
# Epoch 67/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0882 - val_loss: 0.1141
# Epoch 68/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0866 - val_loss: 0.1019
# Epoch 69/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0858 - val_loss: 0.1269
# Epoch 70/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0863 - val_loss: 0.1110
# Epoch 71/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0851 - val_loss: 0.1058
# Epoch 72/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0864 - val_loss: 0.1055
# Epoch 73/100
# 1439/1439 [==============================] - 3s 2ms/step - loss: 0.0836 - val_loss: 0.1018
# Epoch 73: early stopping
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Flight Distance',
#                                                    'Inflight wifi service',
#                                                    'Departure/Arrival time '
#                                                    'convenient',
#                                                    'Ease of Online booking',
#                                                    'Gate location',
#                                                    'Food and drink',
#                                                    'Online boarding',
#                                                    'Seat comfort',
#                                                    'Inflight entertainment'...
#                                                    'Cleanliness',
#                                                    'Departure Delay in Minutes',
#                                                    'Arrival Delay in Minutes']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['Gender', 'Customer Type',
#                                                    'Type of Travel',
#                                                    'Class'])])),
#                 ('nn',
#                  KerasClassifier(callbacks=[<keras.callbacks.EarlyStopping object at 0x0000027C8B0F10A0>], epochs=100, model=<keras.engine.sequential.Sequential object at 0x0000027C8B2BDB20>, validation_split=0.3))])

# %%
# ================================
# Passo 2

clf_metrics(pipe_nn, X_train, y_train, "treino")
print("#"*80)
clf_metrics(pipe_nn, X_test, y_test, "teste")
# Out:
# Métricas de avaliação de treino:
#
# 2055/2055 [==============================] - 6s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.99      0.96     35927
#            1       0.99      0.92      0.95     29812
#
#     accuracy                           0.96     65739
#    macro avg       0.96      0.96      0.96     65739
# weighted avg       0.96      0.96      0.96     65739
#
# ################################################################################
#
# Métricas de avaliação de teste:
#
# 1218/1218 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94     22036
#            1       0.98      0.84      0.91     16928
#
#     accuracy                           0.92     38964
#    macro avg       0.94      0.92      0.92     38964
# weighted avg       0.93      0.92      0.92     38964

# %% [markdown]
# Das métricas acima, verificamos que a rede neural apresenta resultados tão bons quanto o lgbm e xgboost.
